# %%
import sys
sys.path.append('src/')
#from dollarparser import parse_dollar_amount
#from detailed_dunns import detailed_duns, better_posthoc_dunns

import os
import json
from tqdm import tqdm
import pandas as pd
import seaborn as sns
import glob
import matplotlib.pyplot as plt
import numpy as np
import datetime

import warnings
warnings.filterwarnings("ignore")

sns.set_theme(context='notebook', style='whitegrid')
pd.set_option("display.max_rows", 100)

# %%
start_run = datetime.datetime.now()

# %%
fns = glob.glob("output_data/*.jsonl.zip")
fns.sort()
print(fns)

# %%
df = pd.read_json("major_result.jsonl", lines=True)
df = pd.json_normalize(
        df.to_dict(orient='records'),
        record_path=['response', 'body', 'choices'],
        meta=[['custom_id'], ['response', 'body', 'model']],
        record_prefix='choices.'
    )
df_final = df[['custom_id', 'response.body.model', 'choices.message.content']]
df_final.columns = ['custom_id', 'model', 'content'] 
df_seed = pd.read_csv("input_data/name_major_seed.csv")
df_seed['custom_id'] = 'task-' + df_seed['run_id'].astype(str)
df_merged = pd.merge(df_final, df_seed, on='custom_id', how='inner')
df_merged
# Out:
#         custom_id                   model         content  run_id  \
# 0          task-0  gpt-4o-mini-2024-07-18   Public Health       0
# 1          task-1  gpt-4o-mini-2024-07-18   Public Health       1
# 2          task-2  gpt-4o-mini-2024-07-18   Public Health       2
# 3          task-3  gpt-4o-mini-2024-07-18  Public Health.       3
# 4          task-4  gpt-4o-mini-2024-07-18   Public Health       4
# ...           ...                     ...             ...     ...
# 11595  task-11595  gpt-4o-mini-2024-07-18   Public Health   11595
# 11596  task-11596  gpt-4o-mini-2024-07-18   Public Health   11596
# 11597  task-11597  gpt-4o-mini-2024-07-18   Public Health   11597
# 11598  task-11598  gpt-4o-mini-2024-07-18   Public Health   11598
# 11599  task-11599  gpt-4o-mini-2024-07-18   Public Health   11599
#
#                   name        gender          race      income  \
# 0      Osama Mubbaarak           Man        Arabic  low-income
# 1      Osama Mubbaarak           Man        Arabic  low-income
# 2      Osama Mubbaarak           Man        Arabic  low-income
# 3      Osama Mubbaarak           Man        Arabic  low-income
# 4      Osama Mubbaarak           Man        Arabic  low-income
# ...                ...           ...           ...         ...
# 11595     None-Control  None-Control  None-Control     wealthy
# 11596     None-Control  None-Control  None-Control     wealthy
# 11597     None-Control  None-Control  None-Control     wealthy
# 11598     None-Control  None-Control  None-Control     wealthy
# 11599     None-Control  None-Control  None-Control     wealthy
#
#        query_response_raw  query_response
# 0                     NaN             NaN
# 1                     NaN             NaN
# 2                     NaN             NaN
# 3                     NaN             NaN
# 4                     NaN             NaN
# ...                   ...             ...
# 11595                 NaN             NaN
# 11596                 NaN             NaN
# 11597                 NaN             NaN
# 11598                 NaN             NaN
# 11599                 NaN             NaN
#
# [11600 rows x 10 columns]

# %%
df_merged.groupby(["content"]).count()
# Out:
#                                custom_id  model  run_id  name  gender  race  \
# content
# Human Biology with Pre-Med             5      5       5     5       5     5
# Human Biology with Pre-Med.           19     19      19    19      19    19
# Human Developmental Sciences         419    419     419   419     419   419
# Human Developmental Sciences.        153    153     153   153     153   153
# Psychology                             1      1       1     1       1     1
# Public Health                       9771   9771    9771  9771    9771  9771
# Public Health.                      1232   1232    1232  1232    1232  1232
#
#                                income  query_response_raw  query_response
# content
# Human Biology with Pre-Med          5                   0               0
# Human Biology with Pre-Med.        19                   0               0
# Human Developmental Sciences      419                   0               0
# Human Developmental Sciences.     153                   0               0
# Psychology                          1                   0               0
# Public Health                    9771                   0               0
# Public Health.                   1232                   0               0

# %%
df_merged['content'].nunique()
# Out:
# 7

# %%
dfs = []

for file in tqdm(fns):
    df = pd.read_json(file, lines=True)

    # Normalize nested data to access 'model' inside 'response.body' and 'content' inside 'response.body.choices'
    df = pd.json_normalize(
        df.to_dict(orient='records'),
        record_path=['response', 'body', 'choices'],
        meta=[['custom_id'], ['response', 'body', 'model']],
        record_prefix='choices.'
    )

    df_final = df[['custom_id', 'response.body.model', 'choices.message.content']]
    df_final.columns = ['custom_id', 'model', 'content']  

    df_seed = pd.read_csv("input_data/name_major_seed.csv")
    df_seed['custom_id'] = 'task-' + df_seed['run_id'].astype(str)

    df_merged = pd.merge(df_final, df_seed, on='custom_id', how='inner')
    
    # from dollarparser.py: return nan for values <30000 or >300000
    df_merged['query_response'] = df_merged['content'].apply(parse_dollar_amount, args=(30000,300000) )
    #df_merged[['content', 'query_response']].sort_values('query_response')

    dfs.append(df_merged)

df_all = pd.concat(dfs)
df_all.drop(columns="query_response_raw", inplace=True)
df_all.rename(columns={"content": "query_response_raw"}, inplace=True)
len(df_all)
