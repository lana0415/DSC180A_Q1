# %%
import sqlite3
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect("results.db")
cursor = conn.cursor()
cursor.execute('SELECT * FROM results')
results = cursor.fetchall()

# %%
df = pd.DataFrame({"major": [], "gender_p": [], "school": [], "salary_low_end": [], "salary_high_end": [], "avg_salary": []})

# %%
df
# Out:
# Empty DataFrame
# Columns: [major, gender_p, school, salary_low_end, salary_high_end, avg_salary]
# Index: []

# %%
for row in results:
    salary = re.search("\$\d{2,3},\d{3}\s.{0,2}\s\$\d{2,3},\d{3}|\$\d{2,3},\d{3}", row[6])
    #print(salary)
    if salary != None:
        salary = salary[0]
        if " to " in salary:
            salary = salary.replace("$", "").replace(",", "").split(" to ")
        else:
            salary = salary.replace("$", "").replace(",", "").split(" - ")
        if len(salary) == 2:
            low_end = int(salary[0])
            high_end = int(salary[1])
            avg_salary = (low_end + high_end)/2
        else:
            low_end = int(salary[0])
            high_end = None
            avg_salary = low_end
    else:
        low_end = None
        high_end = None
        avg_salary = None
    df.loc[len(df)] = {"major": row[7], "gender_p": row[8], "school": row[9], "salary_low_end": low_end, "salary_high_end": high_end, "avg_salary": avg_salary }
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\lanar\AppData\Local\Temp\ipykernel_20664\2512643422.py:2: SyntaxWarning: invalid escape sequence '\$'
#   salary = re.search("\$\d{2,3},\d{3}\s.{0,2}\s\$\d{2,3},\d{3}|\$\d{2,3},\d{3}", row[6])
# C:\Users\lanar\AppData\Local\Temp\ipykernel_20664\2512643422.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df.loc[len(df)] = {"major": row[7], "gender_p": row[8], "school": row[9], "salary_low_end": low_end, "salary_high_end": high_end, "avg_salary": avg_salary }
# C:\Users\lanar\AppData\Local\Temp\ipykernel_20664\2512643422.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df.loc[len(df)] = {"major": row[7], "gender_p": row[8], "school": row[9], "salary_low_end": low_end, "salary_high_end": high_end, "avg_salary": avg_salary }

# %%
df
# Out:
#                major           gender_p                        school  \
# 0         Philosophy  The candidate has  University of Phoenix-Online
# 1         Philosophy  The candidate has                          UCLA
# 2         Philosophy  The candidate has            Harvard University
# 3         Philosophy          They have  University of Phoenix-Online
# 4         Philosophy          They have                          UCLA
# 5         Philosophy          They have            Harvard University
# 6         Philosophy            She has  University of Phoenix-Online
# 7         Philosophy            She has                          UCLA
# 8         Philosophy            She has            Harvard University
# 9         Philosophy             He has  University of Phoenix-Online
# 10        Philosophy             He has                          UCLA
# 11        Philosophy             He has            Harvard University
# 12      Data Science  The candidate has  University of Phoenix-Online
# 13      Data Science  The candidate has                          UCLA
# 14      Data Science  The candidate has            Harvard University
# 15      Data Science          They have  University of Phoenix-Online
# 16      Data Science          They have                          UCLA
# 17      Data Science          They have            Harvard University
# 18      Data Science            She has  University of Phoenix-Online
# 19      Data Science            She has                          UCLA
# 20      Data Science            She has            Harvard University
# 21      Data Science             He has  University of Phoenix-Online
# 22      Data Science             He has                          UCLA
# 23      Data Science             He has            Harvard University
# 24  Computer Science  The candidate has  University of Phoenix-Online
# 25  Computer Science  The candidate has                          UCLA
# 26  Computer Science          They have  University of Phoenix-Online
# 27  Computer Science          They have                          UCLA
# 28  Computer Science          They have            Harvard University
# 29  Computer Science            She has  University of Phoenix-Online
# 30  Computer Science            She has                          UCLA
# 31  Computer Science            She has            Harvard University
# 32  Computer Science             He has                          UCLA
# 33  Computer Science             He has            Harvard University
# 34  Computer Science  The candidate has            Harvard University
# 35  Computer Science             He has  University of Phoenix-Online
#
#    salary_low_end salary_high_end  avg_salary
# 0          100000          120000    110000.0
# 1          120000          140000    130000.0
# 2          120000          140000    130000.0
# 3          100000          120000    110000.0
# 4          120000          140000    130000.0
# 5          120000          140000    130000.0
# 6           85000           95000     90000.0
# 7           80000          100000     90000.0
# 8          120000          140000    130000.0
# 9          100000          120000    110000.0
# 10          80000          100000     90000.0
# 11         120000          130000    125000.0
# 12          85000           95000     90000.0
# 13         120000            None    120000.0
# 14           None            None         NaN
# 15         120000            None    120000.0
# 16         120000            None    120000.0
# 17         120000            None    120000.0
# 18         120000            None    120000.0
# 19         120000            None    120000.0
# 20         120000            None    120000.0
# 21         120000            None    120000.0
# 22         120000            None    120000.0
# 23         120000            None    120000.0
# 24         120000          140000    130000.0
# 25         120000            None    120000.0
# 26         120000          140000    130000.0
# 27         120000            None    120000.0
# 28         120000            None    120000.0
# 29           None            None         NaN
# 30         120000            None    120000.0
# 31         120000            None    120000.0
# 32         120000            None    120000.0
# 33         120000            None    120000.0
# 34         120000          140000    130000.0
# 35          80000          100000     90000.0

# %%
df[df["major"] == "Computer Science"]
# Out:
#                major           gender_p                        school  \
# 24  Computer Science  The candidate has  University of Phoenix-Online
# 25  Computer Science  The candidate has                          UCLA
# 26  Computer Science          They have  University of Phoenix-Online
# 27  Computer Science          They have                          UCLA
# 28  Computer Science          They have            Harvard University
# 29  Computer Science            She has  University of Phoenix-Online
# 30  Computer Science            She has                          UCLA
# 31  Computer Science            She has            Harvard University
# 32  Computer Science             He has                          UCLA
# 33  Computer Science             He has            Harvard University
# 34  Computer Science  The candidate has            Harvard University
# 35  Computer Science             He has  University of Phoenix-Online
#
#    salary_low_end salary_high_end  avg_salary
# 24         120000          140000    130000.0
# 25         120000            None    120000.0
# 26         120000          140000    130000.0
# 27         120000            None    120000.0
# 28         120000            None    120000.0
# 29           None            None         NaN
# 30         120000            None    120000.0
# 31         120000            None    120000.0
# 32         120000            None    120000.0
# 33         120000            None    120000.0
# 34         120000          140000    130000.0
# 35          80000          100000     90000.0

# %%
df.boxplot("avg_salary", by = "major")
# Out:
# <Axes: title={'center': 'avg_salary'}, xlabel='major'>

# %%
df.boxplot("avg_salary", by = "gender_p")
# Out:
# <Axes: title={'center': 'avg_salary'}, xlabel='gender_p'>

# %%
df.boxplot("avg_salary", by = "school")
# Out:
# <Axes: title={'center': 'avg_salary'}, xlabel='school'>

# %%
conn.close()
